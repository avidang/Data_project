# %% [markdown]
# # Importing libraries

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
kickstarter_df = pd.read_csv("./inputs/kickstarter_data_full.csv", low_memory=False)

# %% [markdown]
# # Drop unnecessary columns

# %%
kickstarter_df.drop(columns=["index", "Unnamed: 0"], inplace=True)

# %% [markdown]
# # Naive feature selection

# %%
kickstarter_df.drop(columns="id", inplace=True)

# %%
kickstarter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20632 entries, 0 to 20631
# Data columns (total 66 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   photo                        20632 non-null  object
#  1   name                         20632 non-null  object
#  2   blurb                        20626 non-null  object
#  3   goal                         20632 non-null  float64
#  4   pledged                      20632 non-null  float64
#  5   state                        20632 non-null  object
#  6   slug                         20632 non-null  object
#  7   disable_communication        20632 non-null  bool
#  8   country                      20632 non-null  object
#  9   currency                     20632 non-null  object
#  10  currency_symbol              20632 non-null  object
#  11  currency_trailing_code       20632 non-null  bool
#  12  deadline                     20632 non-null  object
#  13  state_changed_at             20632 non-null  object
#  14  created_at                   20632 non-null  object
#  15  launched_at                  20632 non-null  object
#  16  staff_pick                   20632 non-null  bool
#  17  backers_count                20632 non-null  int64
#  18  static_usd_rate              20632 non-null  float64
#  19  usd_pledged                  20632 non-null  float64
#  20  creator                      20632 non-null  object
#  21  location                     20587 non-null  object
#  22  category                     18743 non-null  object
#  23  profile                      20632 non-null  object
#  24  spotlight                    20632 non-null  bool
#  25  urls                         20632 non-null  object
#  26  source_url                   20632 non-null  object
#  27  friends                      60 non-null     object
#  28  is_starred                   60 non-null     object
#  29  is_backing                   60 non-null     object
#  30  permissions                  60 non-null     object
#  31  name_len                     20627 non-null  float64
#  32  name_len_clean               20627 non-null  float64
#  33  blurb_len                    20627 non-null  float64
#  34  blurb_len_clean              20627 non-null  float64
#  35  deadline_weekday             20632 non-null  object
#  36  state_changed_at_weekday     20632 non-null  object
#  37  created_at_weekday           20632 non-null  object
#  38  launched_at_weekday          20632 non-null  object
#  39  deadline_month               20632 non-null  int64
#  40  deadline_day                 20632 non-null  int64
#  41  deadline_yr                  20632 non-null  int64
#  42  deadline_hr                  20632 non-null  int64
#  43  state_changed_at_month       20632 non-null  int64
#  44  state_changed_at_day         20632 non-null  int64
#  45  state_changed_at_yr          20632 non-null  int64
#  46  state_changed_at_hr          20632 non-null  int64
#  47  created_at_month             20632 non-null  int64
#  48  created_at_day               20632 non-null  int64
#  49  created_at_yr                20632 non-null  int64
#  50  created_at_hr                20632 non-null  int64
#  51  launched_at_month            20632 non-null  int64
#  52  launched_at_day              20632 non-null  int64
#  53  launched_at_yr               20632 non-null  int64
#  54  launched_at_hr               20632 non-null  int64
#  55  create_to_launch             20632 non-null  object
#  56  launch_to_deadline           20632 non-null  object
#  57  launch_to_state_change       20632 non-null  object
#  58  create_to_launch_days        20632 non-null  int64
#  59  launch_to_deadline_days      20632 non-null  int64
#  60  launch_to_state_change_days  20632 non-null  int64
#  61  SuccessfulBool               20632 non-null  int64
#  62  USorGB                       20632 non-null  int64
#  63  TOPCOUNTRY                   20632 non-null  int64
#  64  LaunchedTuesday              20632 non-null  int64
#  65  DeadlineWeekend              20632 non-null  int64
# dtypes: bool(4), float64(8), int64(25), object(29)
# memory usage: 9.8+ MB

# %% [markdown]
# # Remove features with more that 50% missing values

# %%
kickstarter_df.drop(
    columns=["friends", "is_starred", "is_backing", "permissions"], inplace=True
)

# %% [markdown]
# # Remove features with zero variance

# %%
kickstarter_df.nunique()[kickstarter_df.nunique() == 1]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Check rows with missing values

# %%
kickstarter_df.isnull().any(axis=1).sum()
# Out:
# 1937

# %%
kickstarter_df[
    kickstarter_df[
        [
            "goal",
            "name_len_clean",
            "blurb_len_clean",
            "backers_count",
            "create_to_launch",
            "launch_to_deadline",
            "launch_to_state_change",
            "pledged",
            "usd_pledged",
            "static_usd_rate",
        ]
    ]
    .isnull()
    .any(axis=1)
]
# Out:
#                                                    photo
# 1411   {"small":"https://ksr-ugc.imgix.net/assets/012...  \
# 6744   {"small":"https://ksr-ugc.imgix.net/assets/014...
# 9239   {"small":"https://ksr-ugc.imgix.net/assets/012...
# 11708  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 14805  {"small":"https://ksr-ugc.imgix.net/assets/011...
#
#                                                     name blurb       goal
# 1411                                      N/A (Canceled)   NaN  1500000.0  \
# 6744                                      N/A (Canceled)   NaN    30000.0
# 9239             Star Wars Bluetooth Speakers (Canceled)   NaN    60000.0
# 11708  OF Press - A WordPress Theme and Site Builder ...   NaN     5000.0
# 14805                                    TEST (Canceled)   NaN  1000001.0
#
#        pledged     state                                               slug
# 1411       0.0  canceled                      long-island-school-auditorium  \
# 6744     619.0  canceled              teamstar-sports-community-development
# 9239   36058.0  canceled                       star-wars-bluetooth-speakers
# 11708     71.0  canceled                                           of-press
# 14805     31.0  canceled  caiman-connected-the-ultimate-mobile-device-ac...
#
#        disable_communication country currency  ...
# 1411                   False      US      USD  ...  \
# 6744                   False      AU      AUD  ...
# 9239                   False      GB      GBP  ...
# 11708                  False      US      USD  ...
# 14805                  False      US      USD  ...
#
#                launch_to_deadline      launch_to_state_change
# 1411   30 days 00:00:00.000000000   0 days 05:45:12.000000000  \
# 6744   30 days 00:00:00.000000000  15 days 03:11:27.000000000
# 9239   30 days 00:00:00.000000000   2 days 09:38:30.000000000
# 11708  30 days 00:00:00.000000000  19 days 01:12:46.000000000
# 14805  14 days 00:00:00.000000000  12 days 20:37:21.000000000
#
#       create_to_launch_days launch_to_deadline_days
# 1411                      0                      30  \
# 6744                     34                      30
# 9239                     90                      30
# 11708                     0                      30
# 14805                     6                      14
#
#       launch_to_state_change_days SuccessfulBool  USorGB  TOPCOUNTRY
# 1411                            0              0       1           1  \
# 6744                           15              0       0           0
# 9239                            2              0       1           1
# 11708                          19              0       1           1
# 14805                          12              0       1           1
#
#        LaunchedTuesday  DeadlineWeekend
# 1411                 0                0
# 6744                 0                0
# 9239                 0                0
# 11708                0                1
# 14805                0                0
#
# [5 rows x 62 columns]

# %%
# drop null on ["goal","name_len_clean","blurb_len_clean","backers_count","create_to_launch","launch_to_deadline","launch_to_state_change","pledged","usd_pledged","static_usd_rate"]
kickstarter_df.dropna(
    subset=[
        "goal",
        "name_len_clean",
        "blurb_len_clean",
        "backers_count",
        "create_to_launch",
        "launch_to_deadline",
        "launch_to_state_change",
        "pledged",
        "usd_pledged",
        "static_usd_rate",
    ],
    inplace=True,
)

# %% [markdown]
# # Check the cases of the "state" (dependent) variable

# %%
kickstarter_df["state"].value_counts()
# Out:
# state
# failed        11416
# successful     6018
# canceled       2455
# live            508
# suspended       230
# Name: count, dtype: int64

# %%
kickstarter_df.describe().astype("Float64")
# Out:
#                  goal        pledged  backers_count  static_usd_rate
# count         20627.0        20627.0        20627.0          20627.0  \
# mean     94001.970367   21396.078288     183.708053          1.03936
# std    1335622.241364  120511.450525    1222.158106         0.230413
# min               1.0            0.0            0.0         0.045641
# 25%            4000.0           25.0            2.0              1.0
# 50%           14000.0          697.0           12.0              1.0
# 75%           50000.0         5954.5           63.0              1.0
# max       100000000.0     6225354.98       105857.0         1.715913
#
#          usd_pledged  name_len  name_len_clean  blurb_len  blurb_len_clean
# count        20627.0   20627.0         20627.0    20627.0          20627.0  \
# mean    20918.300266  5.940806        5.292578  18.991177        13.081204
# std    115485.126394  2.826118        2.418168   4.632371         3.283547
# min              0.0       1.0             1.0        1.0              1.0
# 25%             25.0       4.0             3.0       17.0             11.0
# 50%            717.0       6.0             5.0       20.0             13.0
# 75%      6004.752118       8.0             7.0       22.0             15.0
# max       6225354.98      16.0            14.0       35.0             30.0
#
#        deadline_month  ...  launched_at_yr  launched_at_hr
# count         20627.0  ...         20627.0         20627.0  \
# mean         6.707471  ...     2014.752073       12.416881
# std          3.411277  ...        1.261851        5.573344
# min               1.0  ...          2009.0             0.0
# 25%               4.0  ...          2014.0             9.0
# 50%               7.0  ...          2015.0            12.0
# 75%              10.0  ...          2016.0            16.0
# max              12.0  ...          2017.0            23.0
#
#        create_to_launch_days  launch_to_deadline_days
# count                20627.0                  20627.0  \
# mean               49.583313                34.718815
# std               111.106169                11.873524
# min                      0.0                      1.0
# 25%                      3.0                     30.0
# 50%                     14.0                     30.0
# 75%                     45.0                     40.0
# max                   1754.0                     91.0
#
#        launch_to_state_change_days  SuccessfulBool    USorGB  TOPCOUNTRY
# count                      20627.0         20627.0   20627.0     20627.0  \
# mean                     31.174625        0.291754  0.806467    0.816212
# std                      14.277022         0.45458  0.395076    0.387321
# min                            0.0             0.0       0.0         0.0
# 25%                           28.0             0.0       1.0         1.0
# 50%                           30.0             0.0       1.0         1.0
# 75%                           35.0             1.0       1.0         1.0
# max                           91.0             1.0       1.0         1.0
#
#        LaunchedTuesday  DeadlineWeekend
# count          20627.0          20627.0
# mean           0.22519         0.292044
# std           0.417718         0.454714
# min                0.0              0.0
# 25%                0.0              0.0
# 50%                0.0              0.0
# 75%                0.0              1.0
# max                1.0              1.0
#
# [8 rows x 33 columns]

# %% [markdown]
# # Encode the "state" variable

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
kickstarter_df_encoded = kickstarter_df.copy()

# %%
kickstarter_df_encoded["state"] = label_encoder.fit_transform(
    kickstarter_df_encoded["state"]
)

# %%
label_encoder.classes_
# Out:
# array(['canceled', 'failed', 'live', 'successful', 'suspended'],
#       dtype=object)

# %%
label_encoder.inverse_transform([0, 1, 2, 3, 4])
# Out:
# array(['canceled', 'failed', 'live', 'successful', 'suspended'],
#       dtype=object)

# %%
kickstarter_df_encoded["state"].value_counts()
# Out:
# state
# 1    11416
# 3     6018
# 0     2455
# 2      508
# 4      230
# Name: count, dtype: int64

# %%
kickstarter_df_encoded.columns
# Out:
# Index(['photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'backers_count', 'static_usd_rate',
#        'usd_pledged', 'creator', 'location', 'category', 'profile',
#        'spotlight', 'urls', 'source_url', 'name_len', 'name_len_clean',
#        'blurb_len', 'blurb_len_clean', 'deadline_weekday',
#        'state_changed_at_weekday', 'created_at_weekday', 'launched_at_weekday',
#        'deadline_month', 'deadline_day', 'deadline_yr', 'deadline_hr',
#        'state_changed_at_month', 'state_changed_at_day', 'state_changed_at_yr',
#        'state_changed_at_hr', 'created_at_month', 'created_at_day',
#        'created_at_yr', 'created_at_hr', 'launched_at_month',
#        'launched_at_day', 'launched_at_yr', 'launched_at_hr',
#        'create_to_launch', 'launch_to_deadline', 'launch_to_state_change',
#        'create_to_launch_days', 'launch_to_deadline_days',
#        'launch_to_state_change_days', 'SuccessfulBool', 'USorGB', 'TOPCOUNTRY',
#        'LaunchedTuesday', 'DeadlineWeekend'],
#       dtype='object')

# %%
kickstarter_df_encoded[['create_to_launch', 'launch_to_deadline', 'launch_to_state_change']]
# Out:
#                  create_to_launch          launch_to_deadline
# 0      17 days 14:51:39.000000000  36 days 20:47:24.000000000  \
# 1      10 days 06:44:39.000000000  60 days 00:00:00.000000000
# 2       1 days 08:08:58.000000000  60 days 00:00:00.000000000
# 3       0 days 02:11:17.000000000  30 days 00:00:00.000000000
# 4       0 days 15:47:38.000000000  32 days 06:02:33.000000000
# ...                           ...                         ...
# 20627   5 days 13:26:50.000000000  31 days 23:47:41.000000000
# 20628  56 days 02:24:44.000000000  30 days 00:00:00.000000000
# 20629   0 days 23:56:32.000000000  60 days 00:00:00.000000000
# 20630   1 days 17:10:17.000000000  30 days 00:00:00.000000000
# 20631  22 days 22:42:01.000000000  30 days 00:00:00.000000000
#
#            launch_to_state_change
# 0      36 days 20:47:24.000000000
# 1      60 days 00:00:02.000000000
# 2      60 days 00:00:01.000000000
# 3      30 days 00:00:00.000000000
# 4      32 days 06:02:33.000000000
# ...                           ...
# 20627  31 days 23:47:42.000000000
# 20628  30 days 00:00:01.000000000
# 20629  60 days 00:00:04.000000000
# 20630  30 days 00:00:00.000000000
# 20631  30 days 00:00:00.000000000
#
# [20627 rows x 3 columns]

# %% [markdown]
# # Hyphotezis 5: Is features like backers count assotiate with success?

# %%
h7_df = kickstarter_df_encoded[
    [
        "goal",
        "name_len_clean",
        "blurb_len_clean",
        "backers_count",
        "create_to_launch",
        "launch_to_deadline",
        "launch_to_state_change",
        "pledged",
        "usd_pledged",
        "static_usd_rate",
    ]
]

# %%
def convert_to_days(row): # format now 36 days 20:47:24.000000000
    days = row.split(" ")[0]
    return int(days)

# %%
h7_df["create_to_launch"] = h7_df["create_to_launch"].apply(convert_to_days)
h7_df["launch_to_deadline"] = h7_df["launch_to_deadline"].apply(convert_to_days)
h7_df["launch_to_state_change"] = h7_df["launch_to_state_change"].apply(convert_to_days)

# %%
h7_df
# Out:
#            goal  name_len_clean  blurb_len_clean  backers_count
# 0        1500.0             9.0             16.0              0  \
# 1         500.0             4.0             15.0              0
# 2      100000.0             8.0             10.0              5
# 3        5000.0             6.0             13.0              0
# 4        3222.0             7.0             18.0             17
# ...         ...             ...              ...            ...
# 20627   32500.0             5.0             16.0            173
# 20628  100000.0             2.0             15.0             13
# 20629   10000.0             3.0             17.0              0
# 20630    2500.0             1.0              6.0              0
# 20631   50000.0             3.0             17.0             10
#
#        create_to_launch  launch_to_deadline  launch_to_state_change  pledged
# 0                    17                  36                      36      0.0  \
# 1                    10                  60                      60      0.0
# 2                     1                  60                      60    120.0
# 3                     0                  30                      30      0.0
# 4                     0                  32                      32    356.0
# ...                 ...                 ...                     ...      ...
# 20627                 5                  31                      31  25868.0
# 20628                56                  30                      30   1559.0
# 20629                 0                  60                      60      0.0
# 20630                 1                  30                      30      0.0
# 20631                22                  30                      30    380.0
#
#         usd_pledged  static_usd_rate
# 0          0.000000         1.000000
# 1          0.000000         1.000000
# 2        120.000000         1.000000
# 3          0.000000         1.000000
# 4        396.802395         1.114613
# ...             ...              ...
# 20627  25886.197879         1.000703
# 20628   1644.428040         1.054797
# 20629      0.000000         1.000000
# 20630      0.000000         1.000000
# 20631    485.123930         1.276642
#
# [20627 rows x 10 columns]

# %%
def covert_to_usd(row, col_name):
    return (
        row[col_name] * row["static_usd_rate"]
        if row["static_usd_rate"] != 1
        else row[col_name]
    )

# %%
h7_df["usd_goal"] = h7_df.apply(covert_to_usd, args=("goal",), axis=1)
h7_df["usd_pledged"] = h7_df.apply(covert_to_usd, args=("pledged",), axis=1)

# %%
h7_df.drop(columns=["goal", "pledged", "static_usd_rate"], inplace=True)

# %%
h7_df
# Out:
#        name_len_clean  blurb_len_clean  backers_count  create_to_launch
# 0                 9.0             16.0              0                17  \
# 1                 4.0             15.0              0                10
# 2                 8.0             10.0              5                 1
# 3                 6.0             13.0              0                 0
# 4                 7.0             18.0             17                 0
# ...               ...              ...            ...               ...
# 20627             5.0             16.0            173                 5
# 20628             2.0             15.0             13                56
# 20629             3.0             17.0              0                 0
# 20630             1.0              6.0              0                 1
# 20631             3.0             17.0             10                22
#
#        launch_to_deadline  launch_to_state_change   usd_pledged       usd_goal
# 0                      36                      36      0.000000    1500.000000
# 1                      60                      60      0.000000     500.000000
# 2                      60                      60    120.000000  100000.000000
# 3                      30                      30      0.000000    5000.000000
# 4                      32                      32    396.802395    3591.284600
# ...                   ...                     ...           ...            ...
# 20627                  31                      31  25886.197879   32522.863425
# 20628                  30                      30   1644.428040  105479.669000
# 20629                  60                      60      0.000000   10000.000000
# 20630                  30                      30      0.000000    2500.000000
# 20631                  30                      30    485.123930   63832.096000
#
# [20627 rows x 8 columns]

# %%
X = h7_df.drop(columns="usd_pledged")
y = h7_df["usd_pledged"]

# %%
corr_df = h7_df.corr()

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure()
fig.add_trace(
    go.Heatmap(
        z=corr_df.values,
        x=corr_df.columns,
        y=corr_df.columns,
        zmin=-1,
        zmax=1,
    )
)
fig.show()

# %%
def remove_outliers_backers_count(df, col_name):
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    return df[(df[col_name] > lower_bound) & (df[col_name] < upper_bound)]

# %%
h7_df = remove_outliers_backers_count(h7_df, "backers_count")

# %%
h7_df
# Out:
#        name_len_clean  blurb_len_clean  backers_count  create_to_launch
# 0                 9.0             16.0              0                17  \
# 1                 4.0             15.0              0                10
# 2                 8.0             10.0              5                 1
# 3                 6.0             13.0              0                 0
# 4                 7.0             18.0             17                 0
# ...               ...              ...            ...               ...
# 20626             7.0             16.0              9                 2
# 20628             2.0             15.0             13                56
# 20629             3.0             17.0              0                 0
# 20630             1.0              6.0              0                 1
# 20631             3.0             17.0             10                22
#
#        launch_to_deadline  launch_to_state_change  usd_pledged      usd_goal
# 0                      36                      36     0.000000    1500.00000
# 1                      60                      60     0.000000     500.00000
# 2                      60                      60   120.000000  100000.00000
# 3                      30                      30     0.000000    5000.00000
# 4                      32                      32   396.802395    3591.28460
# ...                   ...                     ...          ...           ...
# 20626                  35                      35    72.630572    3595.57285
# 20628                  30                      30  1644.428040  105479.66900
# 20629                  60                      60     0.000000   10000.00000
# 20630                  30                      30     0.000000    2500.00000
# 20631                  30                      30   485.123930   63832.09600
#
# [17562 rows x 8 columns]

# %% [markdown]
# # Split to X and y

# %%
X = h7_df[["backers_count"]]
y = h7_df["usd_pledged"]

# %%
# normalize data
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("y = {:.2f} + {:.2f} * x1".format(lr.intercept_[0], lr.coef_[0][0]))
# Out:
# y = -0.00 + 0.09 * x1

# %%
# plot the linear regression line
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=X_train[:, 0],
        y=y_train[:, 0],
        mode="markers",
        name="train",
    )   
)
fig.add_trace(
    go.Scatter(
        x=X_test[:, 0],
        y=y_test[:, 0],
        mode="markers",
        name="test",
    )
)  
fig.add_trace(
    go.Scatter(
        x=X_train[:, 0],
        y=lr.predict(X_train),
        mode="lines",
        name="train prediction",
    )
)
fig.add_trace(
    go.Scatter(
        x=X_test[:, 0],
        y=lr.predict(X_test),
        mode="lines",
        name="test prediction",
    )   
)
fig.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Mean squared error: {:.2f}".format(mean_squared_error(y_test, lr.predict(X_test))))
# Out:
# Mean squared error: 0.00

# %%
print("Coefficient of determination: {:.2f}".format(r2_score(y_test, lr.predict(X_test))))
# Out:
# Coefficient of determination: 0.29
